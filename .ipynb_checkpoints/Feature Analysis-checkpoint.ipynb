# %%
# %config Completer.use_jedi = False

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('original_data.csv')
data.head()
# Out:
#    Unnamed: 0  age        job  marital    education  default housing loan  \
# 0           0   56  housemaid  married     basic.4y       no      no   no
# 1           1   57   services  married  high.school  unknown      no   no
# 2           2   37   services  married  high.school       no     yes   no
# 3           3   40     admin.  married     basic.6y       no      no   no
# 4           4   56   services  married  high.school       no      no  yes
#
#      contact month  ... campaign  pdays  previous     poutcome  emp.var.rate  \
# 0  telephone   may  ...        1    999         0  nonexistent           1.1
# 1  telephone   may  ...        1    999         0  nonexistent           1.1
# 2  telephone   may  ...        1    999         0  nonexistent           1.1
# 3  telephone   may  ...        1    999         0  nonexistent           1.1
# 4  telephone   may  ...        1    999         0  nonexistent           1.1
#
# ...

# %%
#list all categories
data.age.unique()
# Out:
# array([56, 57, 37, 40, 45, 59, 41, 24, 25, 29, 35, 54, 46, 50, 39, 30, 55,
#        49, 34, 52, 58, 32, 38, 44, 42, 60, 53, 47, 51, 48, 33, 31, 43, 36,
#        28, 27, 26, 22, 23, 20, 21, 61, 19, 18, 70, 66, 76, 67, 73, 88, 95,
#        77, 68, 75, 63, 80, 62, 65, 72, 82, 64, 71, 69, 78, 85, 79, 83, 81,
#        74, 17, 87, 91, 86, 98, 94, 84, 92, 89])

# %%
#iterate the data by ages and store the number of different status in that categories into a dictionary
age_dic = {}
for index,row in data.iterrows():
    key = row['age']
    i = 0 if row['y'] == 'yes' else 1
    tmp = [0]*2
    if key in age_dic:
        tmp = age_dic[key]
    tmp[i] += 1
    age_dic[key] = tmp

# %%
#convert the dictionary into dataframe for easy processing
age_df = pd.DataFrame.from_dict(age_dic)
age_df = age_df.append(dict(age_df.sum()),ignore_index=True).T
#sort the dataframe by the total amount of project
age_df = age_df.sort_index()

# %%
#plot the stacked bar
N = len(age_df)
suc = age_df.iloc[:,0]
fai = age_df.iloc[:,1]
r = age_df[0]/age_df[2]

#separate the project of different status in differnet categories
ind = np.arange(N)
width = 0.35

fig, ax1 = plt.subplots(figsize=(20,20))
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

#setup the vertical bar
p1 = ax1.bar(ind, suc, width, color = 'g')
p2 = ax1.bar(ind, fai, width, bottom=np.array(suc), color = 'r')
p3 = ax2.plot(ind,r,color = 'b')


ax1.set_xlabel('Age',fontsize = 25)
ax1.set_ylabel('Result',fontsize = 25)
ax2.set_ylabel('Rate', fontsize = 25)

plt.title(' Stacked With Result',fontsize = 25)
plt.xticks(ind, age_df.index,fontsize = 20,rotation=90)
plt.yticks(fontsize = 25)
ax2 = plt.axes 

plt.legend((p1[0], p2[0], p3[0]), ('Yes', 'No','Rate'),loc='best',fontsize = 30)
plt.savefig('age_distribute_with_rate.png')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-225cd3619512> in <module>
# ----> 1 data.age.boxplot()
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'boxplot'
